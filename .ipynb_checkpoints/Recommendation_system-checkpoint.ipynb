# %% [markdown]
# # Goal
#
# ### *Is to create a recommendation system that can take an input (crop, PH level) and then output locations and texture of that soil and also, recommend other crops that can grow on that same location*

# %%
#import all needed python libraries

import pandas as pd
#import pandas_profiling

# %% [markdown]
# There are two .xlsx files. We have to read them seperately.

# %%
#Because we imported pandas as pd, read_excel helps us read the dataset that has the .xlsx extension

location = pd.read_excel('Location.xlsx') 
location.head(2)
# Out:
#   Location  Texture   ph
# 0      Ado        3  6.5
# 1    Agatu        9  5.2

# %%
crop = pd.read_excel('Crop.xlsx') 
crop.head(2)
# Out:
#        Crop  Texture PH RANGE
# 0  Potatoes        3  6.0-6.5
# 1      Rice        9  4.0-8.0

# %% [markdown]
# *Both datasets have a common column **Texture** which we can use to merge both dataset as it is prominent if we want a full dataset.*

# %%
df = pd.merge(location, crop, on='Texture') 
df.head()
# Out:
#     Location  Texture   ph      Crop PH RANGE
# 0        Ado        3  6.5  Potatoes  6.0-6.5
# 1        Ado        3  6.5  Tomatoes   5.5-75
# 2  Gwer West        3  6.8  Potatoes  6.0-6.5
# 3  Gwer West        3  6.8  Tomatoes   5.5-75
# 4       Ukum        3  7.4  Potatoes  6.0-6.5

# %%
#lets get the statistical values of our dataset

df.describe()
# Out:
#          Texture         ph
# count  54.000000  54.000000
# mean    5.296296   5.988889
# std     2.994521   1.322043
# min     1.000000   4.100000
# 25%     2.250000   4.600000
# 50%     7.000000   5.800000
# 75%     7.000000   7.400000
# max    11.000000   7.900000

# %%
#since we have merged both dataset, make a dataframe, groupby and find the mean

df1 = pd.DataFrame(df.groupby(['Crop', 'Location', 'ph'])['Texture'].mean()) 
df1.head()
# Out:
#                        Texture
# Crop    Location  ph
# Beans   Logo      7.4      8.0
#         Oju       5.7      8.0
# Cassava Gwer East 4.3      1.0
#         Ogbadibo  7.3      1.0
#         Ohimini   4.6      1.0

# %% [markdown]
# We need to now make the **crop** column our index column as we will use crop as a based to our chat

# %%
crop_matrix = pd.pivot_table(df, index=['Crop'],  columns=['Crop', 'Location','Texture',], values='ph')
crop_matrix.head(10)
# Out:
# Location  Ado Agatu  Apa Buruku Gboko Guma Gwer East Gwer West Katsina-Ala  \
# Texture    3     9    7      10    11   2         1         3           7
# Crop
# Beans     NaN   NaN  NaN    NaN   NaN  NaN       NaN       NaN         NaN
# Cassava   NaN   NaN  NaN    NaN   NaN  NaN       4.3       NaN         NaN
# Citrus    NaN   NaN  7.6    NaN   NaN  NaN       NaN       NaN         4.5
# G/Nut     NaN   NaN  NaN    NaN   NaN  NaN       NaN       NaN         NaN
# Maize     NaN   NaN  NaN    NaN   NaN  NaN       4.3       NaN         NaN
# Mangoes   NaN   NaN  7.6    NaN   NaN  NaN       NaN       NaN         4.5
# Millet    NaN   NaN  NaN    NaN   NaN  NaN       NaN       NaN         NaN
# Okro      NaN   NaN  NaN    NaN   NaN  NaN       4.3       NaN         NaN
# Pepper    NaN   NaN  7.6    NaN   NaN  NaN       NaN       NaN         4.5
# Potatoes  6.5   NaN  NaN    NaN   NaN  NaN       NaN       6.8         NaN
#
# Location Konshisha  ... Obi Ogbadibo Ohimini  Oju Okpokwu Otukpo Tarka Ukum  \
# Texture         7   ...  6        1       1    8       11     2     1    3
# Crop                ...
# Beans          NaN  ... NaN      NaN     NaN  5.7     NaN    NaN   NaN  NaN
# Cassava        NaN  ... NaN      7.3     4.6  NaN     NaN    NaN   7.5  NaN
# Citrus         7.5  ... NaN      NaN     NaN  NaN     NaN    NaN   NaN  NaN
# G/Nut          NaN  ... NaN      NaN     NaN  NaN     NaN    NaN   NaN  NaN
# Maize          NaN  ... NaN      7.3     4.6  NaN     NaN    NaN   7.5  NaN
# Mangoes        7.5  ... NaN      NaN     NaN  NaN     NaN    NaN   NaN  NaN
# Millet         NaN  ... NaN      NaN     NaN  5.7     NaN    NaN   NaN  NaN
# Okro           NaN  ... NaN      7.3     4.6  NaN     NaN    NaN   7.5  NaN
# Pepper         7.5  ... NaN      NaN     NaN  NaN     NaN    NaN   NaN  NaN
# Potatoes       NaN  ... NaN      NaN     NaN  NaN     NaN    NaN   NaN  7.4
#
# Location Ushongo Vandeikya
# Texture       7         7
# Crop
# Beans        NaN       NaN
# Cassava      NaN       NaN
# Citrus       4.6       5.4
# G/Nut        NaN       NaN
# Maize        NaN       NaN
# Mangoes      4.6       5.4
# Millet       NaN       NaN
# Okro         NaN       NaN
# Pepper       4.6       5.4
# Potatoes     NaN       NaN
#
# [10 rows x 23 columns]

# %%
#lets sort values based on crop

df1.sort_values('Crop', ascending=False).head(10)
# Out:
#                           Texture
# Crop     Location    ph
# Yam      Otukpo      7.9      2.0
#          Guma        4.1      2.0
# Tomatoes Ukum        7.4      3.0
#          Gwer West   6.8      3.0
#          Ado         6.5      3.0
# Spinach  Vandeikya   5.4      7.0
#          Ushongo     4.6      7.0
#          Kwande      5.8      7.0
#          Konshisha   7.5      7.0
#          Katsina-Ala 4.5      7.0

# %% [markdown]
# We have used the *pivot table* to make the crop column the index and now, let us use the python correlation function to get similar crops based on correlation using **pearson method**

# %%
similar_df = crop_matrix.corr(method='pearson')
similar_df.head()
# Out:
# Location         Ado Agatu Apa Buruku Gboko Guma Gwer East Gwer West  \
# Texture           3     9   7      10    11   2         1         3
# Location Texture
# Ado      3       NaN   NaN NaN    NaN   NaN  NaN       NaN       NaN
# Agatu    9       NaN   NaN NaN    NaN   NaN  NaN       NaN       NaN
# Apa      7       NaN   NaN NaN    NaN   NaN  NaN       NaN       NaN
# Buruku   10      NaN   NaN NaN    NaN   NaN  NaN       NaN       NaN
# Gboko    11      NaN   NaN NaN    NaN   NaN  NaN       NaN       NaN
#
# Location         Katsina-Ala Konshisha  ... Obi Ogbadibo Ohimini Oju Okpokwu  \
# Texture                   7         7   ...  6        1       1   8       11
# Location Texture                        ...
# Ado      3               NaN       NaN  ... NaN      NaN     NaN NaN     NaN
# Agatu    9               NaN       NaN  ... NaN      NaN     NaN NaN     NaN
# Apa      7               NaN       NaN  ... NaN      NaN     NaN NaN     NaN
# Buruku   10              NaN       NaN  ... NaN      NaN     NaN NaN     NaN
# Gboko    11              NaN       NaN  ... NaN      NaN     NaN NaN     NaN
#
# Location         Otukpo Tarka Ukum Ushongo Vandeikya
# Texture              2     1    3       7         7
# Location Texture
# Ado      3          NaN   NaN  NaN     NaN       NaN
# Agatu    9          NaN   NaN  NaN     NaN       NaN
# Apa      7          NaN   NaN  NaN     NaN       NaN
# Buruku   10         NaN   NaN  NaN     NaN       NaN
# Gboko    11         NaN   NaN  NaN     NaN       NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# Lets write a function that takes two argument and then, sort the output using location.

# %%
def get_similar_texture(one,crop_matrix):
    similar_ph = similar_df[one]*(crop_matrix )
    similar_ph = similar_ph.sort_values(by='Location',ascending = False)

    return similar_ph

# %% [markdown]
# We have to create an *Array* that takes two values, a dataframe that will receive the values for further output after we might have used a *for loop* to check the both values in our array.

# %%
check = [["Yam", 7.9]] 
similar_texture = pd.DataFrame() #this is an empty dataframe
for crop,ph_level in check: #using the for conditional statement, we are checking for two values from the check array
    similar_texture = similar_texture.append(get_similar_texture(crop,ph_level), ignore_index=True) #since similar_texture is an empty dataframe, we are using the append funtion to get values from our def and also input those values of our array in it

similar_texture.head()
similar_texture.sum().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Yam'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20400/106527137.py in <module>
#       2 similar_texture = pd.DataFrame() #this is an empty dataframe
#       3 for crop,ph_level in check: #using the for conditional statement, we are checking for two values from the check array
# ----> 4     similar_texture = similar_texture.append(get_similar_texture(crop,ph_level), ignore_index=True) #since similar_texture is an empty dataframe, we are using the append funtion to get values from our def and also input those values of our array in it
#       5
#       6 similar_texture.head()
#
# ~\AppData\Local\Temp/ipykernel_20400/3300520743.py in get_similar_texture(one, crop_matrix)
#       1 def get_similar_texture(one,crop_matrix):
# ----> 2     similar_ph = similar_df[one]*(crop_matrix )
#       3     similar_ph = similar_ph.sort_values(by='Location',ascending = False)
#       4
#       5     return similar_ph
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3455         if is_single_key:
#    3456             if self.columns.nlevels > 1:
# -> 3457                 return self._getitem_multilevel(key)
#    3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_multilevel(self, key)
#    3506     def _getitem_multilevel(self, key):
#    3507         # self.columns is a MultiIndex
# -> 3508         loc = self.columns.get_loc(key)
#    3509         if isinstance(loc, (slice, np.ndarray)):
#    3510             new_columns = self.columns[loc]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\multi.py in get_loc(self, key, method)
#    2920
#    2921         if not isinstance(key, tuple):
# -> 2922             loc = self._get_level_indexer(key, level=0)
#    2923             return _maybe_to_slice(loc)
#    2924
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\multi.py in _get_level_indexer(self, key, level, indexer)
#    3202         else:
#    3203
# -> 3204             idx = self._get_loc_single_level_index(level_index, key)
#    3205
#    3206             if level > 0 or self._lexsort_depth == 0:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\multi.py in _get_loc_single_level_index(self, level_index, key)
#    2853             return -1
#    2854         else:
# -> 2855             return level_index.get_loc(key)
#    2856
#    2857     def get_loc(self, key, method=None):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Yam'
